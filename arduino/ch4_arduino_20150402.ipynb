# %% [markdown]
# # 1. 스케치의 기본적인 구조와 디지털 출력

# %% [markdown]
# ###- 기본코드 예제

# %%
from IPython.display import HTML
HTML('<iframe width="1000" height="700" src="//123d.circuits.io/circuits/690592-arduino-base-code" frameborder="0" allowfullscreen></iframe>')
# Out:
# <iframe width="1000" height="700" src="//123d.circuits.io/circuits/690592-arduino-base-code" frameborder="0" allowfullscreen></iframe>

# %% [markdown]
# # 2. PWM을 이용한 아날로그 출력

# %% [markdown]
# ### - PWM 이란

# %% [markdown]
# - PWM(Pulse Width Modulation, 펄스 폭 변조) 이란?  PWM은 5V출력을 on/off 상태로 유지하는 것으로 출력하는게 아니라 빠르게 on/off 를 반복하는 것입니다.

# %% [markdown]
# <img src="http://www.hardcopyworld.com/ngine/aduino/wp-content/uploads/sites/3/2014/08/pwm1.gif">

# %% [markdown]
# - 이걸 매우 빠르게 반복하는 겁니다. 그러면 위 예시처럼 on/off 간격(Pulse Width)에 따라 평균전압이 낮아지는 효과가 납니다. 평균전압이 낮아져서 LED를 어둡게 만들 수 있는거죠. 아두이노에서는 500Hz 주파수, 2ms 간격으로 이런 작업을 수행합니다. 그리고 아두이노는 이 단계를 256 단계로 구분할 수 있습니다. 우리가 0V(0) ~ 5V (255)를 256 단계로 구분해서 입력할 수 있다는 뜻입니다. on/off 출력이 아니라 단계적인 출력이 가능하므로 아날로그 출력이라고도 합니다.

# %% [markdown]
# - 아두이노가 가진 Digital 핀 중 PWM 기능을 가진 핀들이 이미 정의되어 있습니다. 아두이노 보드에 있는 각각의 핀 아래에는 핀 번호가 적혀있는데 PWM 기능을 가진 핀은 앞에 (~) 물결 마크가 붙어 있습니다. 3, 5, 6, 9, 10, 11번 핀이 PWM 핀.

# %% [markdown]
# <img src="http://www.hardcopyworld.com/ngine/aduino/wp-content/uploads/sites/3/2014/08/ArduinoUno_r2_front450px.jpg">

# %% [markdown]
# ###- <a href='http://www.tagstudio.net/user_class/5424'>아두이노 핀 구조</a>

# %% [markdown]
# ###- 아날로그 출력 예제

# %%
from IPython.display import HTML
HTML('<iframe width="1000" height="700" src="//123d.circuits.io/circuits/690615-pwm-output" frameborder="0" allowfullscreen></iframe>')
# Out:
# <iframe width="1000" height="700" src="//123d.circuits.io/circuits/690615-pwm-output" frameborder="0" allowfullscreen></iframe>

# %% [markdown]
# #3. 디지털 입력

# %% [markdown]
# ###- 디지털 입력 예제

# %%
from IPython.display import HTML
HTML('<iframe width="1000" height="700" src="//123d.circuits.io/circuits/690667-digital-input" frameborder="0" allowfullscreen></iframe>')
# Out:
# <iframe width="1000" height="700" src="//123d.circuits.io/circuits/690667-digital-input" frameborder="0" allowfullscreen></iframe>

# %% [markdown]
# ###- <a href='http://blog.naver.com/roboholic84/220309707543'>Floating, Pull up,  Pull Down 개념</a>

# %% [markdown]
# - 간단하게 요약하자면, 외부 변화가 생기기 전에 입력 핀을 VCC(5V) 입력 상태로 묶어두는 것이 pull-up, GND(0V) 입력 상태로 묶어두는 것이 pull-down 저항입니다.

# %% [markdown]
# #4. 아날로그 입력

# %% [markdown]
# ###- 아날로그 입력 예제

# %%
from IPython.display import HTML
HTML('<iframe width="1000" height="750" src="//123d.circuits.io/circuits/693676-analog-inputt" frameborder="0" allowfullscreen></iframe>')
# Out:
# <iframe width="1000" height="750" src="//123d.circuits.io/circuits/693676-analog-inputt" frameborder="0" allowfullscreen></iframe>

# %% [markdown]
# ### - <a href='http://www.baldengineer.com/when-to-use-arduinos-pinmode-and-why.html'> 왜  pinMode()를 안쓸 때도 있을까??</a>

# %% [markdown]
# #5. 아두이노 보드에 LCD 연결하기

# %%
from IPython.display import Image
Image(filename='images/lcd.jpg')

# %% [markdown]
# ### - source code

# %% [markdown]
# \#include <LiquidCrystal.h>
#
# LiquidCrystal lcd(12, 11, 5, 4, 3, 2);
#
# void setup() {
#   // put your setup code here, to run once:
#   lcd.begin(16, 2);
#   lcd.print("hello arduino !!");
# }
#
# void loop() {
#   // put your main code here, to run repeatedly:
#   lcd.setCursor(0, 1);
#   lcd.print(millis() / 1000);
# }
